# %%
## PREPARATIONS

import os
import json
from collections import Counter, defaultdict

# Funktion zur rekursiven Rückverfolgung der Provenance eines Datensatzes
"""
# suche nach ids in wasDerivedFrom, in denen die Zielid "tippecc_data:TIPPECC_AWI-ESM-1-REcoM_day_r1i1p1f1__ai__mm_1850_2100__yearsum_mean_1981_2000-2080_2099_prov.nc" in ["prov:generatedEntity"] vorkommt
# für die beiden gefundenen  IDs nimm jeweils die ["prov:usedEntity"] und suche wiederum in welcher ID diese in ["prov:generatedEntity"] vorkommt
# wiederhole bis sich kein neues ["prov:generatedEntity"] mehr findet

# aus entity nimm nur die in wasDerivedFrom vorhandenen entities

# entity
# hadMember
# agent
# activity

sollen live gesucht werden
"""
def find_derivation_chain(target_id):
    new_was_derived_from = {}
    queue = [target_id]
    visited = set()

    while queue:
        current_target = queue.pop(0)
        if current_target in visited:
            continue
        visited.add(current_target)

        matching_ids = [
            key for key, entry in was_derived_from.items()
            if entry.get("prov:generatedEntity") == current_target
        ]

        for _id in matching_ids:
            used_entity = was_derived_from[_id].get("prov:usedEntity")
            new_was_derived_from[_id] = {
                "prov:generatedEntity": current_target,
                "prov:usedEntity": used_entity,
            }


            if used_entity:
                queue.append(used_entity)

    return new_was_derived_from

# Gesuchte Ziel-ID
#target_id = "tippecc_data:TIPPECC_AWI-ESM-1-REcoM_day_r1i1p1f1__ai__mm_1850_2100__yearsum_mean_1981_2000-2080_2099_prov.nc"

base_dir = r"C:\Users\jonas\svelte_scripts\tippecc.github.io\src\lib\generate_rdfjson_rev"
input_file = os.path.join(base_dir, "GRAPH_new.json")

# JSON-LD Datei laden
with open(input_file, "r") as f:
    data_load = json.load(f)

# %%
# Ermittle alle Targets
was_derived_from = data_load.get("wasDerivedFrom", {})
entity_list = data_load.get("entity", {})

targets = set()


for entry in entity_list.keys():
    targets.add(entry)
    #targets.add(entry["prov:usedEntity"])
#print(targets)   
#targets = [target.split(":")[1] for target in targets]

import sys
#sys.exit()
#---------------------------------------------------------------------------------------------------------

# %%
#----------------------------------------------------------------------------------------------------------
# for every entity create a subgraph
#for target_id in targets:
target_id = "TIPPECC_AWI-ESM-1-REcoM_day_r1i1p1f1__ai__mm_1850_2100__yearsum_mean_1981_2000-2080_2099.json"
data = data_load.copy()
target_id = target_id.replace("tippecc_data:", "")
output_file = os.path.join(base_dir, "subgraphs_old", target_id+".json")

target = "tippecc_data:" + target_id.replace(".json", "")


# Starte die Suche und ersetze die Daten
chain = find_derivation_chain(target)
data["wasDerivedFrom"] = chain
#________________________________________________________

# %%
# Die gesamte "Entity"-Struktur
entities = data.get("entity", {})

# Extract unique values from chain
unique_values = set()

for entry in chain.values():
    unique_values.add(entry["prov:generatedEntity"])
    unique_values.add(entry["prov:usedEntity"])

# %%
# Filter entities based on unique_values_list
filtered_entities = {
    entity_id: entity_data
    for entity_id, entity_data in entities.items()
    if entity_id in unique_values
}

data["entity"] = filtered_entities

# %%
#______________________________________________________
# Die gesamte "hadMember"-Struktur
collections = data.get("hadMember", {})


filtered_collections = {
    key: value for key, value in collections.items()
    if value.get("prov:entity") in unique_values
}

data["hadMember"] = filtered_collections

# %%
#_________________________________________________________
# Die gesamte "wasAttributedTo"-Struktur
wasAttributedTo = data.get("wasAttributedTo", {})

filtered_wasAttributedTo = {
    key: value for key, value in wasAttributedTo.items()
    if value.get("prov:entity") in unique_values
}

data["wasAttributedTo"] = filtered_wasAttributedTo

# %%
# Die gesamte "used"-Struktur
used = data.get("used", {})

filtered_used = {
    key: value for key, value in used.items()
    if value.get("prov:entity") in unique_values
}

# Gruppiere nach "prov:activity"
grouped_by_activity = defaultdict(list)
for key, value in filtered_used.items():
    grouped_by_activity[value["prov:activity"]].append((key, value["prov:entity"]))

# %%
#grouped_by_activity

# %%
# Behalte nur die IDs, bei denen es mehrere verschiedene "prov:entity" innerhalb einer Activity gibt
selected_ids_used = {}
for activity, entries in grouped_by_activity.items():
    unique_entities = {entity for _, entity in entries}  # Einzigartige Entities in der Gruppe
    if len(unique_entities) > 1:  # Prüfe, ob es mehr als eine einzigartige Entity gibt
        for key, entity in entries:
            selected_ids_used[key] = used[key]

# Speichere das gefilterte Dictionary zurück in data
data["used"] = selected_ids_used

# %%
selected_ids_used
# Out:
# {'_:id23': {'prov:activity': 'exe:Remap_bilinear_2',
#   'prov:entity': 'tippecc_data:africa05.txt'},
#  '_:id25': {'prov:activity': 'exe:Remap_bilinear_2',
#   'prov:entity': 'tippecc_data:hurs_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_1850_2014'},
#  '_:id230': {'prov:activity': 'exe:Remap_bilinear_25',
#   'prov:entity': 'tippecc_data:africa05.txt'},
#  '_:id232': {'prov:activity': 'exe:Remap_bilinear_25',
#   'prov:entity': 'tippecc_data:pr_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_1850_2014'},
#  '_:id437': {'prov:activity': 'exe:Remap_bilinear_48',
#   'prov:entity': 'tippecc_data:africa05.txt'},
#  '_:id439': {'prov:activity': 'exe:Remap_bilinear_48',
#   'prov:entity': 'tippecc_data:rlds_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_1850_2014'},
#  '_:id644': {'prov:activity': 'exe:Remap_bilinear_71',
#   'prov:entity': 'tippecc_data:africa05.txt'},
#  '_:id646': {'prov:activity': 'exe:Remap_bilinear_71',
#   'prov:entity': 'tippecc_data:rlus_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_1850_2014'},
#  '_:id851': {'prov:activity': 'exe:Remap_bilinear_94',
#   'prov:entity': 'tippecc_data:africa05.txt'},
#  '_:id853': {'prov:activity': 'exe:Remap_bilinear_94',
#   'prov:entity': 'tippecc_data:rsds_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_1850_2014'},
#  '_:id1058': {'prov:activity': 'exe:Remap_bilinear_117',
#   'prov:entity': 'tippecc_data:africa05.txt'},
#  '_:id1060': {'prov:activity': 'exe:Remap_bilinear_117',
#   'prov:entity': 'tippecc_data:rsus_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_1850_2014'},
#  '_:id1265': {'prov:activity': 'exe:Remap_bilinear_140',
#   'prov:entity': 'tippecc_data:africa05.txt'},
#  '_:id1267': {'prov:activity': 'exe:Remap_bilinear_140',
#   'prov:entity': 'tippecc_data:sfcWind_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_1850_2014'},
#  '_:id1472': {'prov:activity': 'exe:Remap_bilinear_163',
#   'prov:entity': 'tippecc_data:africa05.txt'},
#  '_:id1474': {'prov:activity': 'exe:Remap_bilinear_163',
#   'prov:entity': 'tippecc_data:tasmax_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_1850_2014'},
#  '_:id1679': {'prov:activity': 'exe:Remap_bilinear_186',
#   'prov:entity': 'tippecc_data:africa05.txt'},
#  '_:id1681': {'prov:activity': 'exe:Remap_bilinear_186',
#   'prov:entity': 'tippecc_data:tasmin_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_1850_2014'},
#  '_:id2812': {'prov:activity': 'exe:Merge_datasets_374',
#   'prov:entity': 'tippecc_data:hurs_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_18500101-18691231'},
#  '_:id2814': {'prov:activity': 'exe:Merge_datasets_374',
#   'prov:entity': 'tippecc_data:hurs_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_18700101-18891231'},
#  '_:id2816': {'prov:activity': 'exe:Merge_datasets_374',
#   'prov:entity': 'tippecc_data:hurs_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_18900101-19091231'},
#  '_:id2818': {'prov:activity': 'exe:Merge_datasets_374',
#   'prov:entity': 'tippecc_data:hurs_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19100101-19291231'},
#  '_:id2820': {'prov:activity': 'exe:Merge_datasets_374',
#   'prov:entity': 'tippecc_data:hurs_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19300101-19491231'},
#  '_:id2822': {'prov:activity': 'exe:Merge_datasets_374',
#   'prov:entity': 'tippecc_data:hurs_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19500101-19691231'},
#  '_:id2824': {'prov:activity': 'exe:Merge_datasets_374',
#   'prov:entity': 'tippecc_data:hurs_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19700101-19891231'},
#  '_:id2826': {'prov:activity': 'exe:Merge_datasets_374',
#   'prov:entity': 'tippecc_data:hurs_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19900101-20091231'},
#  '_:id2828': {'prov:activity': 'exe:Merge_datasets_374',
#   'prov:entity': 'tippecc_data:hurs_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_20100101-20141231'},
#  '_:id4865': {'prov:activity': 'exe:Merge_datasets_445',
#   'prov:entity': 'tippecc_data:pr_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_18500101-18691231'},
#  '_:id4867': {'prov:activity': 'exe:Merge_datasets_445',
#   'prov:entity': 'tippecc_data:pr_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_18700101-18891231'},
#  '_:id4869': {'prov:activity': 'exe:Merge_datasets_445',
#   'prov:entity': 'tippecc_data:pr_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_18900101-19091231'},
#  '_:id4871': {'prov:activity': 'exe:Merge_datasets_445',
#   'prov:entity': 'tippecc_data:pr_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19100101-19291231'},
#  '_:id4873': {'prov:activity': 'exe:Merge_datasets_445',
#   'prov:entity': 'tippecc_data:pr_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19300101-19491231'},
#  '_:id4875': {'prov:activity': 'exe:Merge_datasets_445',
#   'prov:entity': 'tippecc_data:pr_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19500101-19691231'},
#  '_:id4877': {'prov:activity': 'exe:Merge_datasets_445',
#   'prov:entity': 'tippecc_data:pr_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19700101-19891231'},
#  '_:id4879': {'prov:activity': 'exe:Merge_datasets_445',
#   'prov:entity': 'tippecc_data:pr_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19900101-20091231'},
#  '_:id4881': {'prov:activity': 'exe:Merge_datasets_445',
#   'prov:entity': 'tippecc_data:pr_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_20100101-20141231'},
#  '_:id6670': {'prov:activity': 'exe:Merge_datasets_468',
#   'prov:entity': 'tippecc_data:rlds_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_18500101-18691231'},
#  '_:id6672': {'prov:activity': 'exe:Merge_datasets_468',
#   'prov:entity': 'tippecc_data:rlds_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_18700101-18891231'},
#  '_:id6674': {'prov:activity': 'exe:Merge_datasets_468',
#   'prov:entity': 'tippecc_data:rlds_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_18900101-19091231'},
#  '_:id6676': {'prov:activity': 'exe:Merge_datasets_468',
#   'prov:entity': 'tippecc_data:rlds_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19100101-19291231'},
#  '_:id6678': {'prov:activity': 'exe:Merge_datasets_468',
#   'prov:entity': 'tippecc_data:rlds_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19300101-19491231'},
#  '_:id6680': {'prov:activity': 'exe:Merge_datasets_468',
#   'prov:entity': 'tippecc_data:rlds_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19500101-19691231'},
#  '_:id6682': {'prov:activity': 'exe:Merge_datasets_468',
#   'prov:entity': 'tippecc_data:rlds_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19700101-19891231'},
#  '_:id6684': {'prov:activity': 'exe:Merge_datasets_468',
#   'prov:entity': 'tippecc_data:rlds_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19900101-20091231'},
#  '_:id6686': {'prov:activity': 'exe:Merge_datasets_468',
#   'prov:entity': 'tippecc_data:rlds_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_20100101-20141231'},
#  '_:id8475': {'prov:activity': 'exe:Merge_datasets_491',
#   'prov:entity': 'tippecc_data:rlus_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_18500101-18691231'},
#  '_:id8477': {'prov:activity': 'exe:Merge_datasets_491',
#   'prov:entity': 'tippecc_data:rlus_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_18700101-18891231'},
#  '_:id8479': {'prov:activity': 'exe:Merge_datasets_491',
#   'prov:entity': 'tippecc_data:rlus_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_18900101-19091231'},
#  '_:id8481': {'prov:activity': 'exe:Merge_datasets_491',
#   'prov:entity': 'tippecc_data:rlus_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19100101-19291231'},
#  '_:id8483': {'prov:activity': 'exe:Merge_datasets_491',
#   'prov:entity': 'tippecc_data:rlus_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19300101-19491231'},
#  '_:id8485': {'prov:activity': 'exe:Merge_datasets_491',
#   'prov:entity': 'tippecc_data:rlus_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19500101-19691231'},
#  '_:id8487': {'prov:activity': 'exe:Merge_datasets_491',
#   'prov:entity': 'tippecc_data:rlus_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19700101-19891231'},
#  '_:id8489': {'prov:activity': 'exe:Merge_datasets_491',
#   'prov:entity': 'tippecc_data:rlus_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19900101-20091231'},
#  '_:id8491': {'prov:activity': 'exe:Merge_datasets_491',
#   'prov:entity': 'tippecc_data:rlus_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_20100101-20141231'},
#  '_:id10280': {'prov:activity': 'exe:Merge_datasets_514',
#   'prov:entity': 'tippecc_data:rsds_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_18500101-18691231'},
#  '_:id10282': {'prov:activity': 'exe:Merge_datasets_514',
#   'prov:entity': 'tippecc_data:rsds_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_18700101-18891231'},
#  '_:id10284': {'prov:activity': 'exe:Merge_datasets_514',
#   'prov:entity': 'tippecc_data:rsds_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_18900101-19091231'},
#  '_:id10286': {'prov:activity': 'exe:Merge_datasets_514',
#   'prov:entity': 'tippecc_data:rsds_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19100101-19291231'},
#  '_:id10288': {'prov:activity': 'exe:Merge_datasets_514',
#   'prov:entity': 'tippecc_data:rsds_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19300101-19491231'},
#  '_:id10290': {'prov:activity': 'exe:Merge_datasets_514',
#   'prov:entity': 'tippecc_data:rsds_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19500101-19691231'},
#  '_:id10292': {'prov:activity': 'exe:Merge_datasets_514',
#   'prov:entity': 'tippecc_data:rsds_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19700101-19891231'},
#  '_:id10294': {'prov:activity': 'exe:Merge_datasets_514',
#   'prov:entity': 'tippecc_data:rsds_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19900101-20091231'},
#  '_:id10296': {'prov:activity': 'exe:Merge_datasets_514',
#   'prov:entity': 'tippecc_data:rsds_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_20100101-20141231'},
#  '_:id12085': {'prov:activity': 'exe:Merge_datasets_537',
#   'prov:entity': 'tippecc_data:rsus_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_18500101-18691231'},
#  '_:id12087': {'prov:activity': 'exe:Merge_datasets_537',
#   'prov:entity': 'tippecc_data:rsus_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_18700101-18891231'},
#  '_:id12089': {'prov:activity': 'exe:Merge_datasets_537',
#   'prov:entity': 'tippecc_data:rsus_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_18900101-19091231'},
#  '_:id12091': {'prov:activity': 'exe:Merge_datasets_537',
#   'prov:entity': 'tippecc_data:rsus_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19100101-19291231'},
#  '_:id12093': {'prov:activity': 'exe:Merge_datasets_537',
#   'prov:entity': 'tippecc_data:rsus_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19300101-19491231'},
#  '_:id12095': {'prov:activity': 'exe:Merge_datasets_537',
#   'prov:entity': 'tippecc_data:rsus_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19500101-19691231'},
#  '_:id12097': {'prov:activity': 'exe:Merge_datasets_537',
#   'prov:entity': 'tippecc_data:rsus_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19700101-19891231'},
#  '_:id12099': {'prov:activity': 'exe:Merge_datasets_537',
#   'prov:entity': 'tippecc_data:rsus_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19900101-20091231'},
#  '_:id12101': {'prov:activity': 'exe:Merge_datasets_537',
#   'prov:entity': 'tippecc_data:rsus_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_20100101-20141231'},
#  '_:id13898': {'prov:activity': 'exe:Merge_datasets_560',
#   'prov:entity': 'tippecc_data:sfcWind_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_18500101-18691231'},
#  '_:id13900': {'prov:activity': 'exe:Merge_datasets_560',
#   'prov:entity': 'tippecc_data:sfcWind_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_18700101-18891231'},
#  '_:id13902': {'prov:activity': 'exe:Merge_datasets_560',
#   'prov:entity': 'tippecc_data:sfcWind_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_18900101-19091231'},
#  '_:id13904': {'prov:activity': 'exe:Merge_datasets_560',
#   'prov:entity': 'tippecc_data:sfcWind_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19100101-19291231'},
#  '_:id13906': {'prov:activity': 'exe:Merge_datasets_560',
#   'prov:entity': 'tippecc_data:sfcWind_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19300101-19491231'},
#  '_:id13908': {'prov:activity': 'exe:Merge_datasets_560',
#   'prov:entity': 'tippecc_data:sfcWind_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19500101-19691231'},
#  '_:id13910': {'prov:activity': 'exe:Merge_datasets_560',
#   'prov:entity': 'tippecc_data:sfcWind_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19700101-19891231'},
#  '_:id13912': {'prov:activity': 'exe:Merge_datasets_560',
#   'prov:entity': 'tippecc_data:sfcWind_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19900101-20091231'},
#  '_:id13914': {'prov:activity': 'exe:Merge_datasets_560',
#   'prov:entity': 'tippecc_data:sfcWind_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_20100101-20141231'},
#  '_:id15711': {'prov:activity': 'exe:Merge_datasets_583',
#   'prov:entity': 'tippecc_data:tasmax_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_18500101-18691231'},
#  '_:id15713': {'prov:activity': 'exe:Merge_datasets_583',
#   'prov:entity': 'tippecc_data:tasmax_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_18700101-18891231'},
#  '_:id15715': {'prov:activity': 'exe:Merge_datasets_583',
#   'prov:entity': 'tippecc_data:tasmax_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_18900101-19091231'},
#  '_:id15717': {'prov:activity': 'exe:Merge_datasets_583',
#   'prov:entity': 'tippecc_data:tasmax_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19100101-19291231'},
#  '_:id15719': {'prov:activity': 'exe:Merge_datasets_583',
#   'prov:entity': 'tippecc_data:tasmax_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19300101-19491231'},
#  '_:id15721': {'prov:activity': 'exe:Merge_datasets_583',
#   'prov:entity': 'tippecc_data:tasmax_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19500101-19691231'},
#  '_:id15723': {'prov:activity': 'exe:Merge_datasets_583',
#   'prov:entity': 'tippecc_data:tasmax_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19700101-19891231'},
#  '_:id15725': {'prov:activity': 'exe:Merge_datasets_583',
#   'prov:entity': 'tippecc_data:tasmax_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19900101-20091231'},
#  '_:id15727': {'prov:activity': 'exe:Merge_datasets_583',
#   'prov:entity': 'tippecc_data:tasmax_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_20100101-20141231'},
#  '_:id17524': {'prov:activity': 'exe:Merge_datasets_606',
#   'prov:entity': 'tippecc_data:tasmin_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_18500101-18691231'},
#  '_:id17526': {'prov:activity': 'exe:Merge_datasets_606',
#   'prov:entity': 'tippecc_data:tasmin_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_18700101-18891231'},
#  '_:id17528': {'prov:activity': 'exe:Merge_datasets_606',
#   'prov:entity': 'tippecc_data:tasmin_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_18900101-19091231'},
#  '_:id17530': {'prov:activity': 'exe:Merge_datasets_606',
#   'prov:entity': 'tippecc_data:tasmin_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19100101-19291231'},
#  '_:id17532': {'prov:activity': 'exe:Merge_datasets_606',
#   'prov:entity': 'tippecc_data:tasmin_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19300101-19491231'},
#  '_:id17534': {'prov:activity': 'exe:Merge_datasets_606',
#   'prov:entity': 'tippecc_data:tasmin_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19500101-19691231'},
#  '_:id17536': {'prov:activity': 'exe:Merge_datasets_606',
#   'prov:entity': 'tippecc_data:tasmin_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19700101-19891231'},
#  '_:id17538': {'prov:activity': 'exe:Merge_datasets_606',
#   'prov:entity': 'tippecc_data:tasmin_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_19900101-20091231'},
#  '_:id17540': {'prov:activity': 'exe:Merge_datasets_606',
#   'prov:entity': 'tippecc_data:tasmin_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_gn_20100101-20141231'},
#  '_:id22168': {'prov:activity': 'exe:Merge_datasets_846',
#   'prov:entity': 'tippecc_data:05deg_hurs_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_1850_2014'},
#  '_:id22170': {'prov:activity': 'exe:Merge_datasets_846',
#   'prov:entity': 'tippecc_data:05deg_hurs_day_AWI-ESM-1-REcoM_ssp585_r1i1p1f1_2015_2100'},
#  '_:id22186': {'prov:activity': 'exe:Merge_datasets_850',
#   'prov:entity': 'tippecc_data:05deg_pr_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_1850_2014'},
#  '_:id22188': {'prov:activity': 'exe:Merge_datasets_850',
#   'prov:entity': 'tippecc_data:05deg_pr_day_AWI-ESM-1-REcoM_ssp585_r1i1p1f1_2015_2100'},
#  '_:id22247': {'prov:activity': 'exe:Merge_datasets_861',
#   'prov:entity': 'tippecc_data:05deg_rlds_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_1850_2014'},
#  '_:id22249': {'prov:activity': 'exe:Merge_datasets_861',
#   'prov:entity': 'tippecc_data:05deg_rlds_day_AWI-ESM-1-REcoM_ssp585_r1i1p1f1_2015_2100'},
#  '_:id22265': {'prov:activity': 'exe:Merge_datasets_865',
#   'prov:entity': 'tippecc_data:05deg_rlus_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_1850_2014'},
#  '_:id22267': {'prov:activity': 'exe:Merge_datasets_865',
#   'prov:entity': 'tippecc_data:05deg_rlus_day_AWI-ESM-1-REcoM_ssp585_r1i1p1f1_2015_2100'},
#  '_:id22283': {'prov:activity': 'exe:Merge_datasets_869',
#   'prov:entity': 'tippecc_data:05deg_rsds_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_1850_2014'},
#  '_:id22285': {'prov:activity': 'exe:Merge_datasets_869',
#   'prov:entity': 'tippecc_data:05deg_rsds_day_AWI-ESM-1-REcoM_ssp585_r1i1p1f1_2015_2100'},
#  '_:id22301': {'prov:activity': 'exe:Merge_datasets_873',
#   'prov:entity': 'tippecc_data:05deg_rsus_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_1850_2014'},
#  '_:id22303': {'prov:activity': 'exe:Merge_datasets_873',
#   'prov:entity': 'tippecc_data:05deg_rsus_day_AWI-ESM-1-REcoM_ssp585_r1i1p1f1_2015_2100'},
#  '_:id22319': {'prov:activity': 'exe:Merge_datasets_877',
#   'prov:entity': 'tippecc_data:05deg_sfcWind_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_1850_2014'},
#  '_:id22321': {'prov:activity': 'exe:Merge_datasets_877',
#   'prov:entity': 'tippecc_data:05deg_sfcWind_day_AWI-ESM-1-REcoM_ssp585_r1i1p1f1_2015_2100'},
#  '_:id22337': {'prov:activity': 'exe:Merge_datasets_881',
#   'prov:entity': 'tippecc_data:05deg_tasmax_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_1850_2014'},
#  '_:id22339': {'prov:activity': 'exe:Merge_datasets_881',
#   'prov:entity': 'tippecc_data:05deg_tasmax_day_AWI-ESM-1-REcoM_ssp585_r1i1p1f1_2015_2100'},
#  '_:id22355': {'prov:activity': 'exe:Merge_datasets_885',
#   'prov:entity': 'tippecc_data:05deg_tasmin_day_AWI-ESM-1-REcoM_historical_r1i1p1f1_1850_2014'},
#  '_:id22357': {'prov:activity': 'exe:Merge_datasets_885',
#   'prov:entity': 'tippecc_data:05deg_tasmin_day_AWI-ESM-1-REcoM_ssp585_r1i1p1f1_2015_2100'},
#  '_:id22420': {'prov:activity': 'exe:FUNCTION__XARRAY_ARIDITY_INDEX_898',
#   'prov:entity': 'tippecc_data:TIPPECC_AWI-ESM-1-REcoM_day_r1i1p1f1_pr__mm_1850_2100__yearsum'},
#  '_:id22422': {'prov:activity': 'exe:FUNCTION__XARRAY_ARIDITY_INDEX_898',
#   'prov:entity': 'tippecc_data:TIPPECC_AWI-ESM-1-REcoM_day_r1i1p1f1__evspsblpot__mm_1850_2100__yearsum'},
#  '_:id22429': {'prov:activity': 'exe:Calc_abs._change_899',
#   'prov:entity': 'tippecc_data:TIPPECC_AWI-ESM-1-REcoM_day_r1i1p1f1__ai__mm_1850_2100__yearsum_mean_2080_2099'},
#  '_:id22431': {'prov:activity': 'exe:Calc_abs._change_899',
#   'prov:entity': 'tippecc_data:TIPPECC_AWI-ESM-1-REcoM_day_r1i1p1f1__ai__mm_1850_2100__yearsum_mean_1981_2000'},
#  '_:id22461': {'prov:activity': 'exe:FUNCTION__XARRAY_ARIDITY_INDEX_904',
#   'prov:entity': 'tippecc_data:TIPPECC_AWI-ESM-1-REcoM_day_r1i1p1f1_pr__mm_1850_2100__yearsum'},
#  '_:id22463': {'prov:activity': 'exe:FUNCTION__XARRAY_ARIDITY_INDEX_904',
#   'prov:entity': 'tippecc_data:TIPPECC_AWI-ESM-1-REcoM_day_r1i1p1f1__evspsblpot__mm_1850_2100__yearsum'},
#  '_:id22471': {'prov:activity': 'exe:Calc_pot._ET_905',
#   'prov:entity': 'tippecc_data:TIPPECC_AWI-ESM-1-REcoM_day_r1i1p1f1_tasmax_1850_2100'},
#  '_:id22473': {'prov:activity': 'exe:Calc_pot._ET_905',
#   'prov:entity': 'tippecc_data:TIPPECC_AWI-ESM-1-REcoM_day_r1i1p1f1_tasmin_1850_2100'},
#  '_:id22475': {'prov:activity': 'exe:Calc_pot._ET_905',
#   'prov:entity': 'tippecc_data:TIPPECC_AWI-ESM-1-REcoM_day_r1i1p1f1_hurs_1850_2100'},
#  '_:id22477': {'prov:activity': 'exe:Calc_pot._ET_905',
#   'prov:entity': 'tippecc_data:TIPPECC_AWI-ESM-1-REcoM_day_r1i1p1f1_rsds_1850_2100'},
#  '_:id22479': {'prov:activity': 'exe:Calc_pot._ET_905',
#   'prov:entity': 'tippecc_data:TIPPECC_AWI-ESM-1-REcoM_day_r1i1p1f1_rsus_1850_2100'},
#  '_:id22481': {'prov:activity': 'exe:Calc_pot._ET_905',
#   'prov:entity': 'tippecc_data:TIPPECC_AWI-ESM-1-REcoM_day_r1i1p1f1_rlus_1850_2100'},
#  '_:id22483': {'prov:activity': 'exe:Calc_pot._ET_905',
#   'prov:entity': 'tippecc_data:TIPPECC_AWI-ESM-1-REcoM_day_r1i1p1f1_rlds_1850_2100'},
#  '_:id22485': {'prov:activity': 'exe:Calc_pot._ET_905',
#   'prov:entity': 'tippecc_data:TIPPECC_AWI-ESM-1-REcoM_day_r1i1p1f1_sfcWind_1850_2100'},
#  '_:id22535': {'prov:activity': 'exe:Calc_water_budget_913',
#   'prov:entity': 'tippecc_data:TIPPECC_AWI-ESM-1-REcoM_day_r1i1p1f1_pr_1850_2100'},
#  '_:id22537': {'prov:activity': 'exe:Calc_water_budget_913',
#   'prov:entity': 'tippecc_data:TIPPECC_AWI-ESM-1-REcoM_day_r1i1p1f1__evspsblpot_1850_2100'}}

# %%
#get new activities unique values
unique_exe = set()

for entry in selected_ids_used.values():
    unique_exe.add(entry["prov:activity"])

# %%
#_________________________________________________________
# Die gesamte "wasGeneratedBy"-Struktur
wasGeneratedBy = data.get("wasGeneratedBy", {})
#print(wasGeneratedBy)
filtered_wasGeneratedBy = {
    key: value for key, value in wasGeneratedBy.items()
    if value.get("prov:entity") in unique_values
    and value.get("prov:activity") in unique_exe
}
"""
#if target_id == "tippecc_data:TIPPECC_AWI-ESM-1-REcoM_day_r1i1p1f1__ai__mm_1850_2100__yearsum_mean_1981_2000-2080_2099":
    #print(grouped_by_activity)

# Behalte nur die IDs, bei denen es mehrere verschiedene "prov:entity" innerhalb einer Activity gibt
selected_ids_generated = {}
for activity, entries in grouped_by_activity.items():
    unique_entities = {entity for _, entity in entries}  # Einzigartige Entities in der Gruppe
    if len(unique_entities) > 1:  # Prüfe, ob es mehr als eine einzigartige Entity gibt
        for key, entity in entries:
            selected_ids_generated[key] = wasGeneratedBy[key]
"""
# Speichere das gefilterte Dictionary zurück in data
data["wasGeneratedBy"] = filtered_wasGeneratedBy
#___________________________________________________________
#_______________________________________________________________

# %%
# Gruppiere nach "prov:activity"
#grouped_by_activity = defaultdict(list)
#for key, value in filtered_wasGeneratedBy.items():
    #grouped_by_activity[value["prov:activity"]].append((key, value["prov:entity"]))

# %%
#_________________________________________________________________
# FRAGE: and oder or ??? Wie soll wasInformedBy gebaut werden?
# AKtuell spielt es für die Visualisierung keine Rolle mehr 
# Die gesamte "wasInformedBy"-Struktur
wasInformedBy = data.get("wasInformedBy", {})
#print(wasInformedBy)

filtered_wasInformedBy = {}

for key, value in wasInformedBy.items():
    # Normalize to a list of dicts
    items = value if isinstance(value, list) else [value]

    for item in items:
        if (
            item.get("prov:informed") in unique_exe
            and item.get("prov:informant") in unique_exe
        ):
            #print(item)  # 👈 print each matching value
            filtered_wasInformedBy[key] = item

data["wasInformedBy"] = filtered_wasInformedBy

# %%
#_________________________________________________________________
# Die gesamte "wasAssociatedWith"-Struktur
wasAssociatedWith = data.get("wasAssociatedWith", {})

filtered_wasAssociatedWith = {
    key: value for key, value in wasAssociatedWith.items()
    if value.get("prov:activity") in unique_exe
}

data["wasAssociatedWith"] = filtered_wasAssociatedWith

#________________________________________________________
#get new agents unique values
unique_persons = set()

for entry in filtered_wasAttributedTo.values():
    unique_persons.add(entry["prov:agent"])

# Die gesamte "actedOnBehalfOf"-Struktur

actedOnBehalfOf = data.get("actedOnBehalfOf", {})

filtered_actedOnBehalfOf = {
    key: value for key, value in actedOnBehalfOf.items()
    if value.get("prov:delegate") in unique_persons
}

data["actedOnBehalfOf"] = filtered_actedOnBehalfOf

#_______________________________________________________
#get new software unique values
unique_software = set()
for entry in filtered_wasAssociatedWith.values():
    unique_software.add(entry["prov:agent"])

#get new orgs unique values
unique_orgs = set()
for entry in filtered_actedOnBehalfOf.values():
    unique_orgs.add(entry["prov:responsible"])


# Die gesamte "agent"-Struktur
agent = data.get("agent", {})

filtered_agent = {
    key: value for key, value in agent.items()
    if key in unique_persons
    or key in unique_exe
    or key in unique_software
    or key in unique_orgs
}

data["agent"] = filtered_agent

#_______________________________________________
# Die gesamte "agent"-Struktur
activity = data.get("activity", {})

filtered_activity = {
    key: value for key, value in activity.items()
    if key in unique_exe
}

data["activity"] = filtered_activity
#if target_id == "tippecc_data:TIPPECC_AWI-ESM-1-REcoM_day_r1i1p1f1__ai__mm_1850_2100__yearsum_mean_1981_2000-2080_2099":
    #print(len(filtered_activity))

# Aktualisierte JSON-Datei speichern
with open(output_file, "w") as f:
    json.dump(data, f, indent=4)

print(f"File {target_id} written succesfully to: {base_dir}")
